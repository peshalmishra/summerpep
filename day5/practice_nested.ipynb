# %%
for i in range (5):
    print("*");
# Out:
# *
# *
# *
# *
# *

# %%
for i in range(0,5):
    for j in range(0,5):
        print("*",end="");
    print("");
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
for i in range(0, 5):
    for j in range(i, 5):
        print("*", end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(0, 5):
    for j in range(i, 5):
        print(5-j, end="")
    print()
# Out:
# 54321
# 4321
# 321
# 21
# 1

# %%
for i in range(1, 6):
    for j in range(i):
        print(j+1,end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
for i in range(1, 6):
    a=1
    for j in range(i, 6):
        print(a, end="")
        a+=1
    print()
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
a=1
for i in range(0,5):
    for j in range(0,5):
        print(a,end="")
    a+=1
    print("")
# Out:
# 11111
# 22222
# 33333
# 44444
# 55555

# %%
for i in range(1, 6):
    for j in range(i):
        print(chr(65+j), end="")
    print()
# Out:
# A
# AB
# ABC
# ABCD
# ABCDE

# %%
a=1
for i in range(1, 6):
    for j in range(i):
        print(a,end="")
    a+=1
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555
