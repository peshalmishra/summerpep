# %% [markdown]
# # Python Intro
# This notebook contains 5 simple Python introduction examples.

# %%
# Example 1: Print a message
print("Hello, Python!")

# %%
# Example 2: Basic arithmetic
x = 5
y = 3
print("Sum:", x + y)

# %%
# Example 3: Variables and types
name = "Alice"
age = 20
print(name, "is", age, "years old")

# %%
# Example 4: List creation and indexing
fruits = ["apple", "banana", "cherry"]
print(fruits[0])

# %%
# Example 5: Simple function definition
def greet(person):
    return f"Hello, {person}!"

print(greet("World"))
